# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("./Documents/WR Data (Jul 21 - Jun 22).CSV").drop(['ELC', 'UNIT'], axis=1)
# Out:
# C:\Users\Carter\AppData\Local\Temp\ipykernel_10320\1361824887.py:1: DtypeWarning: Columns (7,17,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Documents/WR Data (Jul 21 - Jun 22).CSV").drop(['ELC', 'UNIT'], axis=1)

# %%
df.head()
# Out:
#                       MAINTENANCE TYPE    EVENT-ID                                                                         DISCREPANCY EVT EQUIP-ID CP  EVT WUC/LCN/UNS WD EVT SYMBOL  REPEATS  RECURS SORTIE NBR EVT-ACT COMP  WCE    PWC WCE EQUIP-ID  WCE WUC/LCN/UNS WCE SYMBOL  SRD IN-SHOP       INSP BY WCE-ACT COMP                                                              WCE NARRATIVE  DDR TM CP.1 TCTO CODE      WUC/LCN/UNS AT WD.1 HMAL MCC  UP  START TIME  STOP DATE  STOP TIME  HRS  CS  CLB CC-AI       USER-ID   AFSC    FSC        PART NBR  SERIAL NBR          LOT NBR     TAG                                                               CORRECTIVE ACTION REMOVED FSC REMOVED PART NBR REMOVED SERIAL NBR  REMOVED LOT NBR REMOVED OP-TIME REMOVED TAG REMOVED FROM PART NBR REMOVED FROM SER NBR INSTALLED FSC INSTALLED PART NBR INSTALLED SERIAL NBR INSTALLED LOT NBR INSTALLED OP-TIME INSTALLED TAG INSTALLED ON PART NBR INSTALLED ON SER NBR REMOVED EQUIP POS REMOVED EQUIP ID  \
# ...

# %%
dist = df['EVT EQUIP-ID'].value_counts()[:10].to_frame().reset_index()
dist.columns = ['Equipment ID', '# Events']
sns.barplot(x='Equipment ID', y='# Events', data=dist)
# Out:
# <AxesSubplot:xlabel='Equipment ID', ylabel='# Events'>

# %%
df[df['EVT EQUIP-ID'] == 'C3642'][:5]
# Out:
#                          MAINTENANCE TYPE    EVENT-ID                                                                                                                    DISCREPANCY EVT EQUIP-ID CP  EVT WUC/LCN/UNS WD EVT SYMBOL  REPEATS  RECURS SORTIE NBR EVT-ACT COMP  WCE    PWC WCE EQUIP-ID  WCE WUC/LCN/UNS WCE SYMBOL  SRD IN-SHOP       INSP BY WCE-ACT COMP                                                   WCE NARRATIVE  DDR TM CP.1 TCTO CODE      WUC/LCN/UNS AT WD.1 HMAL MCC  UP  START TIME  STOP DATE  STOP TIME  HRS  CS  CLB CC-AI       USER-ID       AFSC    FSC        PART NBR  SERIAL NBR          LOT NBR     TAG                                      CORRECTIVE ACTION REMOVED FSC REMOVED PART NBR REMOVED SERIAL NBR  REMOVED LOT NBR REMOVED OP-TIME REMOVED TAG REMOVED FROM PART NBR REMOVED FROM SER NBR INSTALLED FSC INSTALLED PART NBR INSTALLED SERIAL NBR INSTALLED LOT NBR INSTALLED OP-TIME INSTALLED TAG INSTALLED ON PART NBR INSTALLED ON SER NBR REMOVED EQUIP POS  \
# ...
